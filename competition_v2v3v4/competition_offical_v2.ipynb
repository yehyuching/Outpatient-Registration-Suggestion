# %%
#coding=utf-8

import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd

#compile sym_talk dictionary
talk_dic ={}
f_talk = open('symptom_talks.txt', encoding = 'utf-8')
for talk_line in f_talk:  
    talk_words = talk_line.replace('\n', '')
    split_talk = talk_words.split(':')
    talk_dic[split_talk[0]]=split_talk[1]

#compile doc-word set
f = open('./new_SymptomToOutpatient.txt', encoding = 'utf-8').read()
splitF = f.split(':')
words = [w.replace('\n', '') for w in splitF]
depgroup =set()
for dep in words:
    depname = dep.split(',')
    depgroup.update(depname[:-1])
#print(depgroup)

new_f = open('new_SymptomToOutpatient.txt', encoding = 'utf-8')
doc_list= []
for deps in depgroup: 
    slist=[]
    new_f.seek(0)
    for line in new_f:
        sym_dep = line.split(":")
        depset = sym_dep[1].split(",")
        for dep in depset:
            if(dep==deps):
                slist.append(sym_dep[0])
    joined = " ".join(slist)
    doc_list.append(joined)

wf = open('word_doc.txt','w', encoding = 'utf-8')
for dw in doc_list:
    wf.write(dw + "\n")

wf_new = open('word_doc.txt', encoding = 'utf-8')  
doccontent=[]
for line in wf_new:
    line = line.replace("\n","")
    doccontent.append(line)
    
vectorizer = TfidfVectorizer()                  
tfidf = vectorizer.fit_transform(doccontent).toarray()            
vocab = vectorizer.get_feature_names()

#age question
age_answer = input('How old are you? ')
if int(age_answer) < 18:
    print("衛生署宣導：十八歲以下的人士，仍建議看兒科，台灣兒科醫學會也表示，18 歲前的兒童與青少年，身心皆處於發育階段，發病症狀與治療方式與成人有所差異，請選擇至兒科院所就診")
        
sex_answer = input('are you male or female (male= 1 or female=2) ')
if sex_answer == "1":
    sex = "Male"
    print("先生您好!")
if sex_answer == "2":
    sex = "Female" 
    print("小姐您好!")
    
test_set=[]
print("症狀:" + str(vocab))
initial_sym = input('please write the initial symptons (splited by space):')
print("您的初始症狀是:" + initial_sym)
test_set.append(initial_sym)
query_set = []
split_sym=test_set[0].split(" ")
for symid in range(len(split_sym)):
    query_set.append(split_sym[symid])

if sex=="Female":
    query_set.append("睾丸疼痛")
    query_set.append("遺精")
else:
    query_set.append("乳房腫塊")
    query_set.append("白帶")
    query_set.append("閉經")
    query_set.append("痛經")
    query_set.append("宮頸糜爛")
    query_set.append("流產")

testVectorizerArray = vectorizer.transform(test_set).toarray()
cossim = cosine_similarity(testVectorizerArray, tfidf)
#print(cossim)

nonzero_list = np.nonzero(cossim)
argsort = np.argsort(cossim)

a = [argsort[0][i] for i in range(len(argsort[0])) if argsort[0][i] in nonzero_list[1]]
for i in a:
    print(list(depgroup)[i])

newlist = []
for depid in a:
    newlist.append(doccontent[depid])

tfvectorizer = TfidfVectorizer()                       
X = tfvectorizer.fit_transform(newlist)
features = tfvectorizer.get_feature_names()

def top_tfidf_feats(row, features, top_n=10):
    ''' Get top n tfidf values in row and return them with their corresponding feature names.'''
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [features[i] for i in topn_ids]
    df = [(features[i], row[i]) for i in topn_ids]
    feature_df = pd.DataFrame(df)
    feature_df.columns = ['feature', 'tfidf']
    print(feature_df)
    return top_feats

def top_mean_feats(Xtr, features, grp_ids=None, min_tfidf=0.1, top_n=10):
    ''' Return the top n features that on average are most important amongst documents in rows
        indentified by indices in grp_ids. '''
    if grp_ids:
        D = Xtr[grp_ids].toarray()
    else:
        D = Xtr.toarray()

    D[D < min_tfidf] = 0
    tfidf_means = np.max(D, axis=0)
    return top_tfidf_feats(tfidf_means, features, top_n)

top_feats = top_mean_feats(X,features, top_n=20)
choice = 0
answer = "-1"
if len(a)==1:                               ##如果輸入的症狀剛好只對應的一個科別，那麼接回傳答案
    choice=6
    print("recommand:" + str(list(depgroup)[a[len(a)-1]]) )
while(choice<6):
    choice +=1
    print("query_set" + str(query_set))
    if answer=="1":
        print("answer 1" + test_set[0])
        test_set[0] = test_set[0] + " " + query
        print("test_set" + str(test_set))
        # rerun newlist
        testVectorizerArray = vectorizer.transform(test_set).toarray()
        cossim = cosine_similarity(testVectorizerArray, tfidf)
        #print(cossim)
        nonzero_list = np.nonzero(cossim)
        argsort = np.argsort(cossim)
        a = [argsort[0][i] for i in range(len(argsort[0])) if argsort[0][i] in nonzero_list[1]]
        for i in a:
            print(list(depgroup)[i]) 
    
        newlist = []    
        for depid in a:
            newlist.append(doccontent[depid])
        #print(newlist)
        tfvectorizer = TfidfVectorizer()                       
        X = tfvectorizer.fit_transform(newlist)
        features = tfvectorizer.get_feature_names()
        #print('Transform Vectorizer to test set' , str(X.shape))
        top_feats = top_mean_feats(X,features, top_n=10)
        query = ""
        for i in range(len(top_feats)):
            if(top_feats[i] not in query_set):
                query = top_feats[i]
                query_talk = talk_dic[query]
                query_set.append(top_feats[i])
                break
     
    # check top deps > definded_count --> choice to false
    elif answer=="-1":
        print("answer -1")
        query = ""
        # check top deps > definded_count --> choice to false
        for i in range(len(top_feats)):
            if(top_feats[i] not in query_set):
                query = top_feats[i]
                query_talk = talk_dic[query]
                query_set.append(top_feats[i])
                break
    else:
        print("please type (1 or -1)")   ##如果答案不是1或是-1那麼題數不會累計
        choice -=1
    answer = input(query_talk+'(1 or -1) ')
    
if int(age_answer)>18 and str(list(depgroup)[a[len(a)-1]])=="小兒科":   ##如果年齡大於18且選出的答案是小兒科，則印出家醫科
    print("recommand:家醫科" )
else:
    print("recommand:" + str(list(depgroup)[a[len(a)-1]]) )
# Out:
# How old are you? 10
# 衛生署宣導：十八歲以下的人士，仍建議看兒科，台灣兒科醫學會也表示，18 歲前的兒童與青少年，身心皆處於發育階段，發病症狀與治療方式與成人有所差異，請選擇至兒科院所就診
# are you male or female (male= 1 or female=2) 1
# 先生您好!
# 症狀:['乏力', '乳頭內陷', '休克', '低血壓', '便秘', '便血', '全身酸痛', '創傷', '反胃', '口臭', '吞咽困難', '呼吸困難', '咯血', '咳痰', '咳血', '單癱', '嘔吐', '嘔血', '噁心', '宮頸糜爛', '少尿', '尿失禁', '尿痛', '尿血', '尿頻', '心絞痛', '性交疼痛', '惡寒', '抽搐', '抽筋', '氣喘', '流產', '消化不良', '濕疹', '無尿', '牙痛', '玫瑰疹', '畏光', '疼痛', '痢疾', '發熱', '白帶', '皰疹', '盜汗', '睾丸疼痛', '羅音', '羊水過多', '耳痛', '耳鳴', '肘關節脫位', '肝掌', '胃痛', '胸悶', '腰背痛', '腹痛', '腹脹', '血壓升高', '貧血', '遺尿', '遺精', '閉經', '關節痛', '雀斑', '雞眼', '靜脈曲張', '食慾減退', '食欲不振', '鱗屑', '黃疸', '鼻出血', '鼻塞']
# please write the initial symptons (splited by space):噁心
# 您的初始症狀是:噁心
# 外傷外科
# 骨科
# 呼吸內科
# 心胸外科
# 血管外科
# 腎內科
# 婦產科
# 神經內科
# 內分泌科
# 肝膽外科
# 心血管內科
# 風濕科
# 耳鼻喉科
# 血液科
# 腸胃外科
# 傳染科
# 急診科
# 口腔科
# 小兒科
# 消化內科
# 泌尿外科
# 腦外科
# 肛腸外科
#    feature     tfidf
# 0       黃疸  0.732767
# 1       白帶  0.709127
# 2       少尿  0.650001
# 3       創傷  0.593866
# 4       嘔吐  0.554764
# 5       牙痛  0.533927
# 6       腹痛  0.514977
# 7       耳鳴  0.511353
# 8       休克  0.505049
# 9       發熱  0.487102
# 10      尿頻  0.482912
# 11      無尿  0.482912
# 12      耳痛  0.479783
# 13      尿痛  0.466756
# 14    呼吸困難  0.464095
# 15     腰背痛  0.456686
# 16      便秘  0.434806
# 17      抽搐  0.426890
# 18     低血壓  0.422559
# 19      鼻塞  0.408710
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產']
# answer -1
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# please type (1 or -1)
# 你皮膚、眼球有發黃嗎？(1 or -1) 1
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸']
# answer 1噁心
# test_set['噁心 黃疸']
# 外傷外科
# 骨科
# 呼吸內科
# 心胸外科
# 血管外科
# 婦產科
# 神經內科
# 內分泌科
# 心血管內科
# 耳鼻喉科
# 腸胃外科
# 傳染科
# 口腔科
# 腦外科
# 肛腸外科
# 腎內科
# 急診科
# 風濕科
# 泌尿外科
# 血液科
# 小兒科
# 消化內科
# 肝膽外科
#   feature     tfidf
# 0      黃疸  0.732767
# 1      白帶  0.709127
# 2      少尿  0.650001
# 3      創傷  0.593866
# 4      嘔吐  0.554764
# 5      牙痛  0.533927
# 6      腹痛  0.514977
# 7      耳鳴  0.511353
# 8      休克  0.505049
# 9      發熱  0.487102
# 你有少尿的情形嗎？(1 or -1) 1
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸', '少尿']
# answer 1噁心 黃疸
# test_set['噁心 黃疸 少尿']
# 骨科
# 呼吸內科
# 心胸外科
# 血管外科
# 婦產科
# 神經內科
# 耳鼻喉科
# 腸胃外科
# 傳染科
# 口腔科
# 外傷外科
# 腦外科
# 肛腸外科
# 腎內科
# 心血管內科
# 內分泌科
# 泌尿外科
# 小兒科
# 急診科
# 風濕科
# 消化內科
# 肝膽外科
# 血液科
#   feature     tfidf
# 0      黃疸  0.732767
# 1      白帶  0.709127
# 2      少尿  0.650001
# 3      創傷  0.593866
# 4      嘔吐  0.554764
# 5      牙痛  0.533927
# 6      腹痛  0.514977
# 7      耳鳴  0.511353
# 8      休克  0.505049
# 9      發熱  0.487102
# 你有哪裡受傷嗎？(1 or -1) 1
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸', '少尿', '創傷']
# answer 1噁心 黃疸 少尿
# test_set['噁心 黃疸 少尿 創傷']
# 心胸外科
# 呼吸內科
# 婦產科
# 傳染科
# 神經內科
# 耳鼻喉科
# 腸胃外科
# 骨科
# 腦外科
# 腎內科
# 心血管內科
# 肛腸外科
# 小兒科
# 手外科
# 口腔科
# 風濕科
# 泌尿外科
# 外傷外科
# 血管外科
# 急診科
# 內分泌科
# 消化內科
# 肝膽外科
# 血液科
#   feature     tfidf
# 0      黃疸  0.734316
# 1      白帶  0.707457
# 2      少尿  0.648780
# 3      創傷  0.642425
# 4      嘔吐  0.562174
# 5      牙痛  0.532293
# 6      腹痛  0.518752
# 7      耳鳴  0.513192
# 8      雀斑  0.502072
# 9      休克  0.497547
# 有吐嗎？(1 or -1) 3
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸', '少尿', '創傷', '嘔吐']
# please type (1 or -1)
# 有吐嗎？(1 or -1) 2
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸', '少尿', '創傷', '嘔吐']
# please type (1 or -1)
# 有吐嗎？(1 or -1) 1
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸', '少尿', '創傷', '嘔吐']
# answer 1噁心 黃疸 少尿 創傷
# test_set['噁心 黃疸 少尿 創傷 嘔吐']
# 心胸外科
# 神經內科
# 眼科
# 婦產科
# 耳鼻喉科
# 骨科
# 呼吸內科
# 傳染科
# 腎內科
# 手外科
# 心血管內科
# 肛腸外科
# 腸胃外科
# 風濕科
# 口腔科
# 外傷外科
# 血管外科
# 腦外科
# 泌尿外科
# 小兒科
# 急診科
# 內分泌科
# 消化內科
# 肝膽外科
# 血液科
#   feature     tfidf
# 0      黃疸  0.736381
# 1      白帶  0.707599
# 2      創傷  0.652638
# 3      少尿  0.648600
# 4      畏光  0.642403
# 5      嘔吐  0.553653
# 6      牙痛  0.529616
# 7      腹痛  0.527071
# 8      雀斑  0.498396
# 9      耳鳴  0.496936
# 會畏光嗎？(1 or -1) 1
# query_set['噁心', '乳房腫塊', '白帶', '閉經', '痛經', '宮頸糜爛', '流產', '黃疸', '少尿', '創傷', '嘔吐', '畏光']
# answer 1噁心 黃疸 少尿 創傷 嘔吐
# test_set['噁心 黃疸 少尿 創傷 嘔吐 畏光']
# 心胸外科
# 婦產科
# 耳鼻喉科
# 骨科
# 呼吸內科
# 腎內科
# 神經內科
# 手外科
# 心血管內科
# 肛腸外科
# 腸胃外科
# 風濕科
# 口腔科
# 外傷外科
# 血管外科
# 傳染科
# 腦外科
# 泌尿外科
# 小兒科
# 急診科
# 內分泌科
# 消化內科
# 肝膽外科
# 眼科
# 血液科
#   feature     tfidf
# 0      黃疸  0.736381
# 1      白帶  0.707599
# 2      創傷  0.652638
# 3      少尿  0.648600
# 4      畏光  0.642403
# 5      嘔吐  0.553653
# 6      牙痛  0.529616
# 7      腹痛  0.527071
# 8      雀斑  0.498396
# 9      耳鳴  0.496936
# 會不會牙痛？(1 or -1) 1
# recommand:血液科
